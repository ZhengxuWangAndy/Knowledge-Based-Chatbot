# %%
import pandas as pd

# %% [markdown]
# # Converting txt file into list of strings

# %%
filename = '/content/drive/MyDrive/medaa.txt'

with open(filename, 'r') as file:
    data = file.read().replace('\n', '')
sentences = data.split("===")

# %%
df = pd.DataFrame (sentences, columns = ['sentence'])
df.head(10)
# Out:
#                                             sentence
# 0  Q: Is naturopathy as effective as conventional...
# 1  Q: Can randomised trials rely on existing elec...
# 2  Q: Is laparoscopic radical prostatectomy bette...
# 3  Q: Does bacterial gastroenteritis predispose p...
# 4  Q: Is early colonoscopy after admission for ac...
# 5  Q: Does the use of a specialised paediatric re...
# 6  Q: Management of thoracic empyema in childhood...
# 7  Q: Does repeated hyperbaric exposure to 4 atmo...
# 8  Q: Lower urinary tract reconstruction for dupl...
# 9  Q: Is common sheath extravesical reimplantatio...

# %% [markdown]
# # Using Bert

# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)

results = []

for sent in sentences:
  results += nlp(sent)
# Out:
# Downloading:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/829 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/433M [00:00<?, ?B/s]

# %%
print(results[:10])
# Out:
# [{'entity': 'B-MISC', 'score': 0.9898016, 'index': 30, 'word': 'I', 'start': 122, 'end': 123}, {'entity': 'B-MISC', 'score': 0.9301435, 'index': 63, 'word': 'F', 'start': 295, 'end': 296}, {'entity': 'B-MISC', 'score': 0.994001, 'index': 87, 'word': 'I', 'start': 399, 'end': 400}, {'entity': 'B-MISC', 'score': 0.5244876, 'index': 140, 'word': 'La', 'start': 571, 'end': 573}, {'entity': 'I-MISC', 'score': 0.76341075, 'index': 142, 'word': '##os', 'start': 576, 'end': 578}, {'entity': 'B-ORG', 'score': 0.99350893, 'index': 34, 'word': 'RF', 'start': 136, 'end': 138}, {'entity': 'I-ORG', 'score': 0.96142435, 'index': 35, 'word': '##A', 'start': 138, 'end': 139}, {'entity': 'B-ORG', 'score': 0.9957398, 'index': 47, 'word': 'H', 'start': 193, 'end': 194}, {'entity': 'I-ORG', 'score': 0.97865754, 'index': 48, 'word': '&', 'start': 194, 'end': 195}, {'entity': 'I-ORG', 'score': 0.98994, 'index': 49, 'word': 'E', 'start': 195, 'end': 196}]

# %%
output = []
for i, data in enumerate(results):
    output.append(data['word'] + ',' + data['entity'] + ','+str(i)+'\n')

# %%
print(output[0])
# Out:
# I,B-MISC,0

# %%
import csv


with open('ner_aa.csv','w') as f:
  f.writelines(output)
